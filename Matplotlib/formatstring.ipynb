# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'g+--')

# %%
plt.plot(x,y,"r+")

# %%
plt.plot(x,y,"b-")

# %%
plt.plot(x,y,"b+")

# %%
plt.plot(x,y,"b*")

# %%
plt.plot(x,y,"bo")
