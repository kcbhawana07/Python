# %%
import matplotlib.pyplot as plt

# %%
brands = ['Apple', 'Samsung', 'Xiaomi', 'Oppo', 'Vivo']
market_share = [30, 25, 20, 15, 10]

# %%
plt.axis("equal")
plt.pie(market_share,labels=brands)
plt.show()

# %%
plt.savefig("Brand.piechart.png")
