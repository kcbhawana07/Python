# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex'>

# %%
sns.boxplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex'>

# %%
sns.violinplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex'>

# %%
sns.stripplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex'>

# %%
sns.swarmplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex'>
# /Users/bhawanakc/Documents/Python/.venv/lib/python3.9/site-packages/seaborn/categorical.py:3399: UserWarning: 66.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.pointplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex'>
